# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("creditcard.csv")
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
data = data[["BALANCE", "PURCHASES"]]
data.head(10)
# Out:
#        BALANCE  PURCHASES
# 0    40.900749      95.40
# 1  3202.467416       0.00
# 2  2495.148862     773.17
# 3  1666.670542    1499.00
# 4   817.714335      16.00
# 5  1809.828751    1333.28
# 6   627.260806    7091.01
# 7  1823.652743     436.20
# 8  1014.926473     861.49
# 9   152.225975    1281.60

# %%
data.describe()
# Out:
#             BALANCE     PURCHASES
# count   8950.000000   8950.000000
# mean    1564.474828   1003.204834
# std     2081.531879   2136.634782
# min        0.000000      0.000000
# 25%      128.281915     39.635000
# 50%      873.385231    361.280000
# 75%     2054.140036   1110.130000
# max    19043.138560  49039.570000

# %%
fig, ax = plt.subplots()
ax.boxplot(data,
          vert = False,
          showmeans = True,
          meanline = True,
          labels = ("balance", "purchases"),
          patch_artist = True,
          medianprops = {"linewidth" : 2, "color" : "blue"},
          meanprops = {"linewidth" : 2, "color" : "red"})
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e164e813d0>,
#   <matplotlib.lines.Line2D at 0x1e165306d50>,
#   <matplotlib.lines.Line2D at 0x1e165317c50>,
#   <matplotlib.lines.Line2D at 0x1e16532c4d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e165102f10>,
#   <matplotlib.lines.Line2D at 0x1e165314490>,
#   <matplotlib.lines.Line2D at 0x1e16532cf50>,
#   <matplotlib.lines.Line2D at 0x1e16532da10>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x1e1653056d0>,
#   <matplotlib.patches.PathPatch at 0x1e1652f6690>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e165314fd0>,
#   <matplotlib.lines.Line2D at 0x1e16532e410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e1653165d0>,
#   <matplotlib.lines.Line2D at 0x1e16532d490>],
#  'means': [<matplotlib.lines.Line2D at 0x1e165315a10>,
#   <matplotlib.lines.Line2D at 0x1e16532edd0>]}

# %%
kolom = ["BALANCE", "PURCHASES"]

Q1 = data[kolom].quantile(0.25)
Q3 = data[kolom].quantile(0.75)
IQR = Q3-Q1
data = data[~((data[kolom]<(Q1 - 1.5 * IQR)) |
              (data[kolom]>(Q3 + 1.5 * IQR))).any (axis =1)]

plt.boxplot(data[kolom])
plt.xticks([1,2], kolom)
plt.title("Outliear Setelah Dibuang")
plt.show()

# %%
data.describe()
# Out:
#            BALANCE    PURCHASES
# count  7590.000000  7590.000000
# mean   1054.455727   542.351792
# std    1173.232811   646.548508
# min       0.000000     0.000000
# 25%      87.728941    21.225000
# 50%     674.399594   297.210000
# 75%    1593.581535   818.485000
# max    4940.113918  2711.900000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7590 entries, 0 to 8949
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BALANCE    7590 non-null   float64
#  1   PURCHASES  7590 non-null   float64
# dtypes: float64(2)
# memory usage: 177.9 KB

# %%
x_array = np.array(data)

# %%
plt.scatter(data.BALANCE, data.PURCHASES)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_array)
plt.scatter(x_scaled[:,0], x_scaled[:,1], s=10)
plt.show()

# %%
from sklearn.cluster import KMeans
sse = []
index = range(1,10)
for i in index :
    kmeans = KMeans(n_clusters = i, random_state = 0, n_init='auto')
    kmeans.fit(x_scaled)
    sse_ = kmeans.inertia_
    sse.append(sse_)
    print(i,sse)
# Out:
# 1 [15180.0]
# 2 [15180.0, 10023.041506076344]
# 3 [15180.0, 10023.041506076344, 5080.22749902957]
# 4 [15180.0, 10023.041506076344, 5080.22749902957, 4077.783066621074]
# 5 [15180.0, 10023.041506076344, 5080.22749902957, 4077.783066621074, 3288.773163128977]
# 6 [15180.0, 10023.041506076344, 5080.22749902957, 4077.783066621074, 3288.773163128977, 2324.9172862330074]
# 7 [15180.0, 10023.041506076344, 5080.22749902957, 4077.783066621074, 3288.773163128977, 2324.9172862330074, 2034.2365132235882]
# 8 [15180.0, 10023.041506076344, 5080.22749902957, 4077.783066621074, 3288.773163128977, 2324.9172862330074, 2034.2365132235882, 1791.8294118601455]
# 9 [15180.0, 10023.041506076344, 5080.22749902957, 4077.783066621074, 3288.773163128977, 2324.9172862330074, 2034.2365132235882, 1791.8294118601455, 1484.2691963963327]

# %%
plt.plot(index, sse)
plt.show()

# %%
kmeans = KMeans (n_clusters = 3,random_state =0, n_init='auto')
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=3, n_init='auto', random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.45242515, -0.41729774],
#        [-0.14073716,  1.7124404 ],
#        [ 1.6482047 , -0.3570451 ]])

# %%
output = plt.scatter(x_scaled[:,0],x_scaled[:,1], s=10, c = kmeans.labels_)

centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c="red", s=10)
plt.title("KMEANS Clustering Credit Card")
plt.xlabel("Balance")
plt.ylabel("Purchases")
plt.colorbar(output)
plt.show()

# %%
from sklearn.metrics import davies_bouldin_score
labels = kmeans.labels_
davies_bouldin_score(x_scaled, labels)
# Out:
# 0.7222871313630544
